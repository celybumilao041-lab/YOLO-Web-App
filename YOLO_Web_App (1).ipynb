# %%
# !pip install ultralytics gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import gradio as gr
print("YOLOv8 version:", YOLO.__module__)
print("Gradio version:", gr.__version__)
print("All installed successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 version: ultralytics.models.yolo.model
# Gradio version: 5.50.0
# All installed successfully!

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
print("Model loaded successfully!")
# Out:
# ...
# Model loaded successfully!

# %%
import gradio as gr
from PIL import Image
import numpy as np

def detect_objects(image):
    results = model(image)
    annotated = results[0].plot()
    return Image.fromarray(annotated)

# %%
app = gr.Interface(
    fn=detect_objects,
    inputs=gr.Image(type="numpy", label="Upload an Image"),
    outputs=gr.Image(type="pil", label="Detection Result"),
    title="YOLOv8 Object Detector",
    description="Upload any image and YOLO will detect objects like people, cars, animals, and more!"
)

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://94fa06e7d9565a8c6c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://94fa06e7d9565a8c6c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
